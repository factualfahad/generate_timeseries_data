# %%
import numpy as np
from numpy import genfromtxt
import matplotlib.pylab as plt
# %matplotlib inline

# %%
my_data = genfromtxt('/Users/fahad/Documents/_data/Boston/processed/Boston_timeseries/level_7/drt2yr0', delimiter=',')
lgnd=[];
plt.figure(figsize=(10,5))
for _ in range(0,7):
    plt.plot(my_data[_],'-*');
    lgnd.append(_);
plt.legend(lgnd)
plt.xticks([int(_) for _ in np.linspace(0,24,25)])
plt.title('MIT Killin Court - 7 digit geohash')
# Out:
# Text(0.5,1,'MIT Killin Court - 7 digit geohash')

# %%
my_data = genfromtxt('/Users/fahad/Documents/_data/Boston/processed/Boston_timeseries/level_6/drt2yr', delimiter=',')
lgnd=[];
plt.figure(figsize=(10,5))
for _ in range(0,7):
    plt.plot(my_data[_],'-*');
    lgnd.append(_);
plt.legend(lgnd)
plt.xticks([int(_) for _ in np.linspace(0,24,25)])
plt.title('the MIT area with Kendall square - 6 digit geohash')
# Out:
# Text(0.5,1,'the MIT area with Kendall square - 6 digit geohash')

# %%
my_data = genfromtxt('/Users/fahad/Documents/_data/Boston/processed/Boston_timeseries/level_7/drt2ymq', delimiter=',')
lgnd=[];
plt.figure(figsize=(10,5))
for _ in range(0,7):
    plt.plot(my_data[_],'-*');
    lgnd.append(_);
plt.legend(lgnd)
plt.xticks([int(_) for _ in np.linspace(0,24,25)])
plt.title('area surrounding trader joes on Boylston - 7 digit geohash');

# %%
my_data = genfromtxt('/Users/fahad/Documents/_data/Boston/processed/Boston_timeseries/level_7/drt2y5w', delimiter=',')
lgnd=[];
plt.figure(figsize=(10,5))
for _ in range(0,7):
    plt.plot(my_data[_],'-*');
    lgnd.append(_);
plt.legend(lgnd)
plt.xticks([int(_) for _ in np.linspace(0,24,25)])
plt.title('Mueseum of fine arts- 7 digit geohash');

# %%
my_data = genfromtxt('/Users/fahad/Documents/_data/Boston/processed/Boston_timeseries/level_8/drt2yytz', delimiter=',')
lgnd=[];
plt.figure(figsize=(10,5))
for _ in range(0,7):
    plt.plot(my_data[_],'-*');
    lgnd.append(_);
plt.legend(lgnd)
plt.title('MBTA Park Street- 8 digit geohash');
plt.xticks([int(_) for _ in np.linspace(0,24,25)])
#print('wow its capturing the daily spikes in the MBTA traffic at ')
# Out:
# ([<matplotlib.axis.XTick at 0x114fbf400>,
# ...
#  <a list of 25 Text xticklabel objects>)

# %%
my_data_1 = genfromtxt('/Users/fahad/Documents/_data/Boston/processed/Boston_timeseries/level_8/drt2yp2t', delimiter=',')
my_data_2 = genfromtxt('/Users/fahad/Documents/_data/Boston/processed/Boston_timeseries/level_8/drt2yp2v', delimiter=',')
my_data_3 = genfromtxt('/Users/fahad/Documents/_data/Boston/processed/Boston_timeseries/level_8/drt2yp2w', delimiter=',')
my_data_4 = genfromtxt('/Users/fahad/Documents/_data/Boston/processed/Boston_timeseries/level_8/drt2yp2y', delimiter=',')
my_data_5 = genfromtxt('/Users/fahad/Documents/_data/Boston/processed/Boston_timeseries/level_8/drt2yp2n', delimiter=',')
my_data_6 = genfromtxt('/Users/fahad/Documents/_data/Boston/processed/Boston_timeseries/level_8/drt2yp2j', delimiter=',')
my_data=my_data_1;
lgnd=[];
plt.figure(figsize=(10,5))
for _ in range(0,7):
    plt.plot(my_data[_],'-*');
    lgnd.append(_);
plt.legend(lgnd)
plt.title('Pacific Cafe in Cambridge');
plt.xticks([int(_) for _ in np.linspace(0,24,25)])
print('This is still suffering from low presence of people in the area ')
# Out:
# This is still suffering from low presence of people in the area

# %%
my_data = genfromtxt('/Users/fahad/Documents/_data/Boston/processed/Boston_timeseries/level_7/drt2ycv', delimiter=',')
lgnd=[];
plt.figure(figsize=(10,5))
for _ in range(0,4):
    plt.plot(my_data[_],'-*');
    lgnd.append(_);
plt.legend(lgnd)
plt.title('Target');
plt.xticks([int(_) for _ in np.linspace(0,24,25)])
# Out:
# ([<matplotlib.axis.XTick at 0x115b1acc0>,
# ...
#  <a list of 25 Text xticklabel objects>)

# %%
my_data = genfromtxt('/Users/fahad/Documents/_data/Boston/processed/Boston_timeseries/level_7/drt2ycv', delimiter=',')
lgnd=[];
plt.figure(figsize=(10,5))
for _ in range(5,7):
    plt.plot(my_data[_],'-*');
    lgnd.append(_);
plt.legend(lgnd)
plt.title('Target');
plt.xticks([int(_) for _ in np.linspace(0,24,25)])
# Out:
# ([<matplotlib.axis.XTick at 0x1160ba048>,
# ...
#  <a list of 25 Text xticklabel objects>)

# %%
my_data = genfromtxt('/Users/fahad/Documents/_data/Boston/processed/Boston_timeseries/level_7/drt2yz8', delimiter=',')
lgnd=[];
plt.figure(figsize=(10,5))
for _ in range(0,7):
    plt.plot(my_data[_],'-*');
    lgnd.append(_);
plt.legend(lgnd)
plt.title('Charles MGH area');
plt.xticks([int(_) for _ in np.linspace(0,24,25)])
# Out:
# ([<matplotlib.axis.XTick at 0x115b93f28>,
# ...
#  <a list of 25 Text xticklabel objects>)
